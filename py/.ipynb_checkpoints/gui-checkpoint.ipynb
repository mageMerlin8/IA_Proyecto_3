# %%
# %run parser.ipynb
# %run graficas.ipynb

# %%
a = read_all_data(6)
print_overview(a[:1])
# Out:
# Dias: 1
# Muertos: 0

# %%
print_overview(a[:])
# Out:
# Dias: 33
# Muertos: 45

# %%
plot_area(a,13)
# Out:
# Area #13
# Es principalmente RESIDENCIAL
# Dia: 99

# %%
a[:1].shape[0]
# Out:
# 1

# %%
# for i in range(1,2):
#     plot_area(a,i,5)

# %%
a.head()
# Out:
#    Area_10_moyotes  Area_10_moyotes_infectados_area_sepa_1  \
# 0              816                                       2
# 1              816                                       2
# 2              816                                       2
# 3              816                                       2
# 4              816                                       2
#
#    Area_10_moyotes_infectados_area_sepa_2  \
# 0                                       4
# 1                                       4
# 2                                       4
# 3                                       4
# 4                                       4
#
#    Area_10_moyotes_infectados_area_sepa_3  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
#
#    Area_10_moyotes_infectados_area_sepa_4  Area_10_muertes  \
# ...

# %%
a.Area
# Out:
# Index(['Area_10_moyotes', 'Area_10_moyotes_infectados_area_sepa_1',
#        'Area_10_moyotes_infectados_area_sepa_2',
#        'Area_10_moyotes_infectados_area_sepa_3',
#        'Area_10_moyotes_infectados_area_sepa_4', 'Area_10_muertes',
#        'Area_10_muertes_por_sepa_sepa_1', 'Area_10_muertes_por_sepa_sepa_2',
#        'Area_10_muertes_por_sepa_sepa_3', 'Area_10_muertes_por_sepa_sepa_4',
#        ...
#        'Area_7_moyotes_infectados_area_sepa_2',
#        'Area_7_moyotes_infectados_area_sepa_3',
#        'Area_7_moyotes_infectados_area_sepa_4', 'Area_7_muertes',
#        'Area_7_muertes_por_sepa_sepa_1', 'Area_7_muertes_por_sepa_sepa_2',
#        'Area_7_muertes_por_sepa_sepa_3', 'Area_7_muertes_por_sepa_sepa_4',
#        'Area_7_personas_infectadas',
#        'Area_7_personas_infectadas_por_sepa_sepa_1'],
#       dtype='object', length=300)

# %%
a.loc[:]['Area_12_personas_infectadas_por_sepa_sepa_3'].sum()
# Out:
# 103
