# %%
# %run parser.ipynb
# %run graficas.ipynb

# %%
a = read_all_data(0)
print_overview(a[:])
# Out:
# Dias: 100
# Muertos: 346

# %%
plot_area(a,1,10)
# Out:
# Area #1
# Es principalmente RESIDENCIAL
# Dia: 10

# %%
for i in range(1,4):
    plot_area(a,i,50)
# Out:
# Area #1
# Es principalmente RESIDENCIAL
# Dia: 50
# Area #2
# Es principalmente LABORAL
# Dia: 50
# Area #3
# Es principalmente RECREATIVA
# Dia: 50
