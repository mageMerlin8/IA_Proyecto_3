# %% [markdown]
# ### Aqui se muere la enferemedad con el tiempo medio normal

# %%
# %run parser.ipynb
# %run graficas.ipynb
# a = read_all_data(3)
a = pd.read_csv('prueba_2.csv')
print_overview(a[:1])
# Out:
# Dias: 1
# Muertos: 0

# %%
print_overview(a[:])
# Out:
# Dias: 100
# Muertos: 277
