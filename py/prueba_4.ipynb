# %% [markdown]
# ### Empiezan 0.1% de la poblacion de moyotes infectados entonces la poblacion de moyotes explota antes del panico. Esto tambien hace que la cantidad de charcos crezca mucho antes de que se den cuenta del problema

# %%
# %run parser.ipynb
# %run graficas.ipynb
# a = read_all_data(6)
a = pd.read_csv('prueba_4.csv')
print_overview(a[:1])
# Out:
# Dias: 1
# Muertos: 0

# %%
print_overview(a[:])
# Out:
# Dias: 34
# Muertos: 49

# %%
a.to_csv('prueba_4.csv')
