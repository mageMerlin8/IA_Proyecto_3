# %%
# %run parser.ipynb
# %run graficas.ipynb

# %%
a = read_all_data(1)
print_overview(a[:])
# Out:
# Dias: 100
# Muertos: 418

# %%
plot_area(a,1,99)
# Out:
# Area #1
# Es principalmente RECREATIVA
# Dia: 99

# %%
# for i in range(1,2):
#     plot_area(a,i,5)
