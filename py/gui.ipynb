# %%
# %run parser.ipynb
# %run graficas.ipynb

# %%
a = read_all_data(1)
print_overview(a[:])
# Out:
# Dias: 100
# Muertos: 231

# %%
plot_area(a,1,3)
# Out:
# Area #1
# Es principalmente RESIDENCIAL
# Dia: 3

# %%
for i in range(1,4):
    plot_area(a,i,0)
# Out:
# Area #1
# Es principalmente RESIDENCIAL
# Dia: 0
# Area #2
# Es principalmente LABORAL
# Dia: 0
# Area #3
# Es principalmente RECREATIVA
# Dia: 0
