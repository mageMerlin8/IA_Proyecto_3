# %% [markdown]
# ### Empieza 15% de la población de moyotes infectada y logra acabar con 2/3 de la poblacion antes de ser erradicado

# %%
# %run parser.ipynb
# %run graficas.ipynb
# a = read_all_data(5)
a = pd.read_csv('prueba_3.csv')
print_overview(a[:1])
# Out:
# Dias: 1
# Muertos: 0

# %%
print_overview(a[:])
# Out:
# Dias: 100
# Muertos: 2001

# %%
a.to_csv('prueba_3.csv')
